# %% [markdown]
# ## Import necessary libraries

# %%
import yfinance as yf
import numpy as np
import pandas as pd

# %% [markdown]
# # Data collection

# %% [markdown]
# ## Fetch daily OHLCV data

# %%
tsla = yf.download('TSLA', start='2019-01-01', end='2025-03-26')
xly = yf.download('XLY', start='2019-01-01', end='2025-03-26')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
print(tsla.tail())
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2025-03-19  235.860001  241.410004  229.199997  231.610001  111993800
# 2025-03-20  236.259995  238.000000  230.050003  233.350006   99028300
# 2025-03-21  248.710007  249.520004  234.550003  234.990005  132728700
# 2025-03-24  278.390015  278.640015  256.329987  258.079987  169079900
# 2025-03-25  288.140015  288.200012  271.279999  283.600006  150361500

# %%
print(xly.head())
# Out:
# Price           Close       High        Low       Open   Volume
# Ticker            XLY        XLY        XLY        XLY      XLY
# Date
# 2019-01-02  94.046097  94.574020  91.246207  91.745849  6840800
# 2019-01-03  92.009811  93.555877  91.849550  93.329626  6346000
# 2019-01-04  95.054817  95.752431  93.065670  93.254212  7269100
# 2019-01-07  97.204224  97.826417  95.460187  95.507318  6263100
# 2019-01-08  98.278931  98.806854  96.883697  98.212940  9391000

# %% [markdown]
# ## Fetching sentiment scores from the API

# %%
import requests
import pandas as pd

# Step 1: Make the API request
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&date_from=20250101T0130&date_to=20250301T0130&limit=1000&tickers=tsla&apikey=A6UVECU631A2QQFG'
response = requests.get(url)

# Step 2: Parse the JSON
if response.status_code == 200:
    sentiment_json = response.json()
    articles = sentiment_json['feed']
    sentiment_df = pd.DataFrame(articles)
else:
    raise Exception("API call failed:", response.status_code)

# Step 3: Extract time and sentiment score
# Not all rows have sentiment data, so we need to drop those
sentiment_df = sentiment_df.dropna(subset=['ticker_sentiment'])

# Flatten the nested 'ticker_sentiment' column (which is a list of dicts)
# We'll explode it, then extract the sentiment_score
sentiment_df = sentiment_df.explode('ticker_sentiment')
sentiment_df['sentiment_score'] = sentiment_df['ticker_sentiment'].apply(lambda x: float(x['ticker_sentiment_score']) if isinstance(x, dict) else None)

# Step 4: Convert timestamp to date only
sentiment_df['date'] = pd.to_datetime(sentiment_df['time_published'], format="%Y%m%dT%H%M%S").dt.date

# Step 5: Group by date and compute average sentiment score
daily_sentiment = sentiment_df.groupby('date')['sentiment_score'].mean().to_frame(name='avg_sentiment_score')

# Done! You now have a clean DataFrame
print(daily_sentiment.tail())
len(daily_sentiment)
# Out:
#             avg_sentiment_score
# date
# 2025-03-25             0.074306
# 2025-03-26             0.091014
# 2025-03-27             0.053512
# 2025-03-28             0.083595
# 2025-03-29            -0.227385
# 25

# %% [markdown]
# # Indicator Calculation

# %% [markdown]
# ## Compute VI+ and VI- for TSLA

# %%
def calculate_vortex(df, value, n=14):
    high = df[("High", value)]
    low = df[("Low", value)]
    close = df[("Close", value)]

    # Calculate VM+ and VM-
    vm_plus = abs(high - low.shift(1))   # |Today's High - Yesterday's Low|
    vm_minus = abs(low - high.shift(1))  # |Today's Low - Yesterday's High|

    # Calculate True Range (TR)
    tr = pd.concat([
        high - low,
        abs(high - close.shift(1)),
        abs(low - close.shift(1))
    ], axis=1).max(axis=1)

    # Rolling sum for lookback period
    sum_vm_plus = vm_plus.rolling(window=n).sum()
    sum_vm_minus = vm_minus.rolling(window=n).sum()
    sum_tr = tr.rolling(window=n).sum()

    # Compute VI+ and VI-
    vi_plus = sum_vm_plus / sum_tr
    vi_minus = sum_vm_minus / sum_tr

    return vi_plus, vi_minus

# %%
vi_plus, vi_minus = calculate_vortex(tsla, "TSLA")
vortex_tsla = pd.DataFrame({
    "VI+": vi_plus,
    "VI-": vi_minus
})

vortex_tsla.tail(5)
# Out:
#                  VI+       VI-
# Date
# 2025-03-19  0.676217  1.075796
# 2025-03-20  0.691925  1.079572
# 2025-03-21  0.680821  1.077461
# 2025-03-24  0.805184  0.911496
# 2025-03-25  0.843336  0.858793

# %% [markdown]
# ## Calculate Volume Weighted Sentiment

# %%
# Step 2: Ensure datetime index for sentiment data
# If daily_sentiment index is of type `date`, convert to datetime
daily_sentiment.index = pd.to_datetime(daily_sentiment.index)

# Step 3: Extract volume from tsla
volume_series = tsla["Volume"]
volume_series.index = pd.to_datetime(volume_series.index)

# Step 4: Merge everything by date
combined_df = vortex_tsla.join(daily_sentiment, how="left")
volume_series.name = "Volume"
combined_df = combined_df.join(volume_series, how="left")


combined_df = combined_df.dropna()

# Show result
print(combined_df.tail())

len(daily_sentiment)
# Out:
#                  VI+       VI-  avg_sentiment_score       TSLA
# Date
# 2025-03-19  0.676217  1.075796             0.100433  111993800
# 2025-03-20  0.691925  1.079572             0.081449   99028300
# 2025-03-21  0.680821  1.077461             0.078977  132728700
# 2025-03-24  0.805184  0.911496             0.092694  169079900
# 2025-03-25  0.843336  0.858793             0.074306  150361500
# 25

# %%
# Rename 'TSLA' column to 'Volume'
combined_df = combined_df.rename(columns={"TSLA": "Volume"})

# Create a new column: volume-weighted sentiment
combined_df["volume_weighted_sentiment"] = combined_df["avg_sentiment_score"] * combined_df["Volume"]

# Drop any rows with missing data (just in case)
combined_df = combined_df.dropna()

# Show result
print(combined_df.tail())
# Out:
#                  VI+       VI-  avg_sentiment_score     Volume  \
# Date
# 2025-03-19  0.676217  1.075796             0.100433  111993800
# 2025-03-20  0.691925  1.079572             0.081449   99028300
# 2025-03-21  0.680821  1.077461             0.078977  132728700
# 2025-03-24  0.805184  0.911496             0.092694  169079900
# 2025-03-25  0.843336  0.858793             0.074306  150361500
#
#             volume_weighted_sentiment
# Date
# 2025-03-19               1.124792e+07
# 2025-03-20               8.065711e+06
# 2025-03-21               1.048249e+07
# 2025-03-24               1.567263e+07
# 2025-03-25               1.117283e+07

# %% [markdown]
# ## Derive ATR for Volatility Adjustments

# %%
high = tsla["High"]
low = tsla["Low"]
close = tsla["Close"]

# True Range (TR)
tr = pd.concat([
    high - low,
    abs(high - close.shift(1)),
    abs(low - close.shift(1))
], axis=1).max(axis=1)

# ATR(10)
atr_10 = tr.rolling(window=10).mean()

# Optional: Add to your combined_df
combined_df["ATR_10"] = atr_10
print(combined_df.tail())
# Out:
#                  VI+       VI-  avg_sentiment_score     Volume  \
# Date
# 2025-03-19  0.676217  1.075796             0.100433  111993800
# 2025-03-20  0.691925  1.079572             0.081449   99028300
# 2025-03-21  0.680821  1.077461             0.078977  132728700
# 2025-03-24  0.805184  0.911496             0.092694  169079900
# 2025-03-25  0.843336  0.858793             0.074306  150361500
#
#             volume_weighted_sentiment     ATR_10
# Date
# 2025-03-19               1.124792e+07  19.417001
# 2025-03-20               8.065711e+06  18.303999
# 2025-03-21               1.048249e+07  18.248999
# 2025-03-24               1.567263e+07  16.974998
# 2025-03-25               1.117283e+07  16.663000

# %% [markdown]
# # Signal Generation

# %%
# Step 1: Compute crossovers
vi_cross_up = (combined_df["VI+"].shift(1) < combined_df["VI-"].shift(1)) & (combined_df["VI+"] > combined_df["VI-"])
vi_cross_down = (combined_df["VI+"].shift(1) > combined_df["VI-"].shift(1)) & (combined_df["VI+"] < combined_df["VI-"])

# Step 2: Compute sentiment condition
combined_df["vw_sentiment_5d_avg"] = combined_df["volume_weighted_sentiment"].rolling(window=5).mean()
sentiment_positive = combined_df["vw_sentiment_5d_avg"] > 0

# Step 3: Compute ATR condition (in % of price)
# Use Close price from tsla DataFrame
price = tsla["Close"]
price.index = pd.to_datetime(price.index)
combined_df["price"] = price
combined_df["atr_pct"] = combined_df["ATR_10"] / combined_df["price"] * 100

# Step 4: Choose your strategy: Aggressive (ATR < 3) or Conservative (ATR ≥ 3)
# Let’s say we use both for now
aggressive_entry = combined_df["atr_pct"] < 3
conservative_entry = combined_df["atr_pct"] >= 3

# Step 5: Combine conditions
buy_signal = vi_cross_up & sentiment_positive & (aggressive_entry | conservative_entry)
sell_signal = vi_cross_down  # We'll handle trailing stop in backtest logic

# Step 6: Add to DataFrame
combined_df["signal"] = 0
combined_df.loc[buy_signal, "signal"] = 1
combined_df.loc[sell_signal, "signal"] = -1

print(combined_df["signal"].value_counts())

combined_df.head(5)
# Out:
# signal
# 0    15
# Name: count, dtype: int64
#                  VI+       VI-  avg_sentiment_score     Volume  \
# Date
# 2025-03-05  0.736173  1.221730             0.108449   94042900
# 2025-03-06  0.650565  1.297453             0.066316   98451600
# 2025-03-07  0.598733  1.333346             0.072116  102369600
# 2025-03-10  0.500406  1.297775             0.032752  189076900
# 2025-03-11  0.488991  1.372778             0.009234  174896400
#
#             volume_weighted_sentiment     ATR_10  vw_sentiment_5d_avg  \
# Date
# 2025-03-05               1.019882e+07  20.471997                  NaN
# 2025-03-06               6.528928e+06  20.950000                  NaN
# 2025-03-07               7.382454e+06  20.446001                  NaN
# 2025-03-10               6.192651e+06  22.943004                  NaN
# 2025-03-11               1.615057e+06  21.619003         6.383582e+06
#
#                  price    atr_pct  signal
# Date
# 2025-03-05  279.100006   7.335004       0
# 2025-03-06  263.450012   7.952173       0
# 2025-03-07  262.670013   7.783911       0
# 2025-03-10  222.149994  10.327709       0
# 2025-03-11  230.580002   9.375923       0

# %%
import vectorbt as vbt

# Entry and exit signals
entries = combined_df["signal"] == 1
exits = combined_df["signal"] == -1

# Price series
price = combined_df["price"]

portfolio = vbt.Portfolio.from_signals(
    close=price,
    entries=entries,
    exits=exits,
    init_cash=100_000,
    fees=0.001,
    sl_stop=0.03  # <-- this is the trailing stop-loss!
)

# %%
# Plot equity curve
portfolio.plot().show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File timedeltas.pyx:729, in pandas._libs.tslibs.timedeltas.parse_timedelta_unit()
#
# KeyError: 'b'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 2
#       1 # Plot equity curve
# ----> 2 portfolio.plot().show()
#
# File /opt/anaconda3/lib/python3.11/site-packages/vectorbt/generic/plots_builder.py:180, in PlotsBuilderMixin.plots(self, subplots, tags, column, group_by, silence_warnings, template_mapping, settings, filters, subplot_settings, show_titles, hide_id_labels, group_id_labels, make_subplots_kwargs, **layout_kwargs)
#     178 # Resolve defaults
#     179 if silence_warnings is None:
# --> 180     silence_warnings = self.plots_defaults['silence_warnings']
#     181 if show_titles is None:
#     182     show_titles = self.plots_defaults['show_titles']
#
# File /opt/anaconda3/lib/python3.11/site-packages/vectorbt/portfolio/base.py:5377, in Portfolio.plots_defaults(self)
#    5373 returns_cfg = settings['returns']
#    5374 portfolio_plots_cfg = settings['portfolio']['plots']
#    5376 return merge_dicts(
# -> 5377     PlotsBuilderMixin.plots_defaults.__get__(self),
#    5378     dict(
#    5379         settings=dict(
#    5380             year_freq=returns_cfg['year_freq'],
#    5381             trades_type=self.trades_type
#    5382         )
#    5383     ),
#    5384     portfolio_plots_cfg
#    5385 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/vectorbt/generic/plots_builder.py:56, in PlotsBuilderMixin.plots_defaults(self)
#      51 from vectorbt._settings import settings
#      52 plots_builder_cfg = settings['plots_builder']
#      54 return merge_dicts(
#      55     plots_builder_cfg,
# ---> 56     dict(settings=dict(freq=self.wrapper.freq))
#      57 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/vectorbt/base/array_wrapper.py:434, in ArrayWrapper.freq(self)
#     432         return freq_to_timedelta(self.index.freq)
#     433     if self.index.inferred_freq is not None:
# --> 434         return freq_to_timedelta(self.index.inferred_freq)
#     435 return freq
#
# File /opt/anaconda3/lib/python3.11/site-packages/vectorbt/utils/datetime_.py:23, in freq_to_timedelta(arg)
#      20 """`pd.to_timedelta` that uses unit abbreviation with number."""
#      21 if isinstance(arg, str) and not arg[0].isdigit():
#      22     # Otherwise "ValueError: unit abbreviation w/o a number"
# ---> 23     return pd.Timedelta(1, unit=arg)
#      24 return pd.Timedelta(arg)
#
# File timedeltas.pyx:1871, in pandas._libs.tslibs.timedeltas.Timedelta.__new__()
#
# File timedeltas.pyx:731, in pandas._libs.tslibs.timedeltas.parse_timedelta_unit()
#
# ValueError: invalid unit abbreviation: B

# %%
# Full stats
portfolio.stats()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/vectorbt/generic/stats_builder.py:396: UserWarning:
#
# Metric 'sharpe_ratio' requires frequency to be set
#
# /opt/anaconda3/lib/python3.11/site-packages/vectorbt/generic/stats_builder.py:396: UserWarning:
#
# Metric 'calmar_ratio' requires frequency to be set
#
# /opt/anaconda3/lib/python3.11/site-packages/vectorbt/generic/stats_builder.py:396: UserWarning:
#
# Metric 'omega_ratio' requires frequency to be set
#
# /opt/anaconda3/lib/python3.11/site-packages/vectorbt/generic/stats_builder.py:396: UserWarning:
#
# Metric 'sortino_ratio' requires frequency to be set
# Start                         2025-02-04 00:00:00
# End                           2025-03-25 00:00:00
# Period                                         35
# Start Value                              100000.0
# End Value                                100000.0
# Total Return [%]                              0.0
# Benchmark Return [%]                   -26.534249
# Max Gross Exposure [%]                        0.0
# Total Fees Paid                               0.0
# Max Drawdown [%]                              NaN
# Max Drawdown Duration                         NaN
# Total Trades                                    0
# Total Closed Trades                             0
# Total Open Trades                               0
# Open Trade PnL                                0.0
# Win Rate [%]                                  NaN
# Best Trade [%]                                NaN
# Worst Trade [%]                               NaN
# Avg Winning Trade [%]                         NaN
# Avg Losing Trade [%]                          NaN
# Avg Winning Trade Duration                    NaN
# Avg Losing Trade Duration                     NaN
# Profit Factor                                 NaN
# Expectancy                                    NaN
# dtype: object

# %%
xly.head()
# Out:
# Price           Close       High        Low       Open   Volume
# Ticker            XLY        XLY        XLY        XLY      XLY
# Date
# 2019-01-02  94.046112  94.574035  91.246222  91.745864  6840800
# 2019-01-03  92.009842  93.555908  91.849581  93.329657  6346000
# 2019-01-04  95.054817  95.752431  93.065670  93.254212  7269100
# 2019-01-07  97.204208  97.826402  95.460172  95.507303  6263100
# 2019-01-08  98.278908  98.806831  96.883674  98.212917  9391000

# %%
tsla['VI+'], tsla['VI-'] = calculate_vortex(tsla, 'TSLA')
xly['VI+'], xly['VI-'] = calculate_vortex(xly, 'XLY')
spy['VI+'], spy['VI-'] = calculate_vortex(spy, 'SPY')

# %%
spy.head(20)
# Out:
# Price            Close        High         Low        Open     Volume  \
# Ticker             SPY         SPY         SPY         SPY        SPY
# Date
# 2019-01-02  226.954697  227.889090  223.117390  223.144604  126925200
# 2019-01-03  221.538956  225.494199  221.049078  225.185752  144140700
# 2019-01-04  228.959625  229.612786  224.224218  224.605226  142628800
# 2019-01-07  230.764877  232.189121  228.324599  229.231765  103139100
# 2019-01-08  232.932968  233.422845  230.420129  232.978343  102512600
# 2019-01-09  234.021591  234.874329  232.406837  233.649650   95006600
# 2019-01-10  234.847137  235.101143  231.780912  232.470367   96823900
# 2019-01-11  234.937836  234.965050  233.168851  233.758503   73858100
# 2019-01-14  233.504532  234.320976  232.606446  233.014654   70908200
# 2019-01-15  236.180618  236.498132  233.876409  233.885490   85208300
# 2019-01-16  236.752136  237.650221  236.407409  236.616039   77636700
# 2019-01-17  238.548340  239.419239  235.826842  235.872217   96118400
# 2019-01-18  241.723450  242.195194  238.584663  240.380862  127900300
# 2019-01-22  238.457581  240.453356  236.824693  240.235645  115531200
# 2019-01-23  238.956604  240.208498  236.461897  239.500909   86030300
# 2019-01-24  239.083588  239.673268  237.750053  238.775155   59204100
# 2019-01-25  241.106552  241.941157  239.183365  240.952322   96883400
# 2019-01-28  239.274078  239.337559  237.486961  238.938431   85613700
# 2019-01-29  238.956604  239.990759  238.112946  239.419268   66136300
# 2019-01-30  242.739456  243.592194  239.718606  240.489702   92473700
#
# Price            VI+       VI-
# Ticker
# Date
# 2019-01-02       NaN       NaN
# 2019-01-03       NaN       NaN
# 2019-01-04       NaN       NaN
# 2019-01-07       NaN       NaN
# 2019-01-08       NaN       NaN
# 2019-01-09       NaN       NaN
# 2019-01-10       NaN       NaN
# 2019-01-11       NaN       NaN
# 2019-01-14       NaN       NaN
# 2019-01-15       NaN       NaN
# 2019-01-16       NaN       NaN
# 2019-01-17       NaN       NaN
# 2019-01-18       NaN       NaN
# 2019-01-22       NaN       NaN
# 2019-01-23  1.130636  0.628504
# 2019-01-24  1.243887  0.588641
# 2019-01-25  1.294371  0.643291
# 2019-01-28  1.114521  0.723057
# 2019-01-29  1.081450  0.729692
# 2019-01-30  1.050552  0.675234

# %%
# Out:
#                                                title  \
# 0  EXCLUSIVE: Which Magnificent 7 Stock Will Perf...
# 1  New Inflation Data Dismays Bulls, CoreWeave IP...
# 2  Assessing Apple's Performance Against Competit...
# 3  Apple's Options Frenzy: What You Need to Know ...
# 4  Trading The SPY As PCE Inflation Report Takes ...
#
#                                                  url   time_published  \
# 0  https://www.benzinga.com/tech/25/03/44544129/e...  20250328T190544
# 1  https://www.benzinga.com/markets/equities/25/0...  20250328T161558
# 2  https://www.benzinga.com/insights/news/25/03/4...  20250328T150055
# 3  https://www.benzinga.com/insights/options/25/0...  20250328T134533
# 4  https://www.benzinga.com/markets/equities/25/0...  20250328T125805
#
#                authors                                            summary  \
# 0        [Chris Katje]  Benzinga readers pick their favorite Magnifice...
# 1   [The Arora Report]  To gain an edge, this is what you need to know...
# 2  [Benzinga Insights]  Amidst the fast-paced and highly competitive b...
# 3  [Benzinga Insights]  Investors with a lot of money to spend have ta...
# 4               [RIPS]  Good Morning Traders! In today's Market Clubho...
#
#                                         banner_image    source  \
# 0  https://cdn.benzinga.com/files/images/story/20...  Benzinga
# 1  https://thearorareport.com/wp-content/uploads/...  Benzinga
# 2  https://www.benzinga.com/files/images/story/20...  Benzinga
# 3  https://www.benzinga.com/files/images/story/20...  Benzinga
# 4  https://www.benzinga.com/next-assets/images/sc...  Benzinga
#
#   category_within_source     source_domain  \
# 0                Trading  www.benzinga.com
# 1                Markets  www.benzinga.com
# 2                Trading  www.benzinga.com
# 3                Markets  www.benzinga.com
# 4                Trading  www.benzinga.com
#
#                                               topics  overall_sentiment_score  \
# 0  [{'topic': 'Retail & Wholesale', 'relevance_sc...                 0.266216
# 1  [{'topic': 'Technology', 'relevance_score': '0...                 0.240809
# 2  [{'topic': 'Earnings', 'relevance_score': '0.8...                 0.265078
# 3  [{'topic': 'Financial Markets', 'relevance_sco...                 0.185008
# 4  [{'topic': 'Economy - Monetary', 'relevance_sc...                 0.084859
#
#   overall_sentiment_label                                   ticker_sentiment
# 0        Somewhat-Bullish  [{'ticker': 'MSFT', 'relevance_score': '0.1984...
# 1        Somewhat-Bullish  [{'ticker': 'MSFT', 'relevance_score': '0.1725...
# 2        Somewhat-Bullish  [{'ticker': 'AAPL', 'relevance_score': '0.4680...
# 3        Somewhat-Bullish  [{'ticker': 'EVR', 'relevance_score': '0.06568...
# 4                 Neutral  [{'ticker': 'MSFT', 'relevance_score': '0.0813...

# %%
sentiment_df
# Out:
#                                                 title  \
# 0   EXCLUSIVE: Which Magnificent 7 Stock Will Perf...
# 1   New Inflation Data Dismays Bulls, CoreWeave IP...
# 2   Assessing Apple's Performance Against Competit...
# 3   Apple's Options Frenzy: What You Need to Know ...
# 4   Trading The SPY As PCE Inflation Report Takes ...
# 5   EU To Issue Minimal Fines To Apple And Meta To...
# 6           3 Northern Mutual Funds for Solid Returns
# 7   2 Breakout Growth Stocks You Can Buy and Hold ...
# 8   Intel's SuperFluid Cooling Tech 'Possibly Suit...
# 9   Should Strive 500 ETF  ( STRV )  Be on Your In...
# 10  Should Invesco Dividend Achievers ETF  ( PFM )...
# 11  3 Subtle Ways Warren Buffett Is Investing in t...
# 12  Competitor Analysis: Evaluating Apple And Comp...
# 13  Prediction: Apple Will Soar Over the Next 5 Ye...
# 14  How To Trade SPY With Initial Jobless Claims I...
# 15  Can the Tide Turn for 'Magnificent Seven' Stoc...
# 16  Is Nvidia the Next $5 Trillion Stock? Or Will ...
# 17                           Apple's Microsoft Moment
# 18  Is Apple About to Make a Massive Bet on Nvidia...
# 19  After Siri Leadership Change, Apple Makes Anot...
# 20  Zacks Investment Ideas feature highlights: Ver...
# 21  Zacks Earnings Trends Highlights: Meta, Tesla,...
# 22  Nvidia And Apple Supplier Foxconn To Present E...
# 23  Steve Jobs Warned 34 Years Ago About America B...
# 24           Breaking Down the Mag 7 Earnings Outlook
# 25           Breaking Down the Mag 7 Earnings Outlook
# 26  2 Wonderful High-Tech ETFs That Still Look Lik...
# 27  Apple  ( AAPL )  Stock Moves -0.99%: What You ...
# 28  Meta Is Paying 'Way Above Market Rate' For Rea...
# 29     These 3 Companies are Cash Generating Machines
# 30  Insights Into Apple's Performance Versus Peers...
# 31  The Zacks Analyst Blog Highlights Apple, Alpha...
# 32            How To Trade The Top Tech Stocks Today?
# 33                 Stock Market News For Mar 26, 2025
# 34  Alibaba, BMW Team Up To Bring AI-Powered Smart...
# 35  Should SPDR Portfolio S&P 500 Value ETF  ( SPY...
# 36  Is Vident U.S. Equity Strategy ETF  ( VUSE )  ...
# 37  Should Goldman Sachs MarketBeta U.S. 1000 Equi...
# 38  Is WisdomTree U.S. LargeCap ETF  ( EPS )  a St...
# 39  Nasdaq Correction: 3 Unstoppable Growth Stocks...
# 40  3 Reasons to Buy Berkshire Hathaway Stock Like...
# 41  TSMC's $165 Billion Bet On US Chip Manufacturi...
# 42  The "Magnificent Seven" Stocks Are Selling Off...
# 43  Big Tech Companies Employ Majority Of H-1B Vis...
# 44  ARM Stock Declines 10% in a Month: Buy or Wait...
# 45  Spotify Stock Soars 130% in a Year: Is it Stil...
# 46  Market Mechanics Driving Stocks, Tariffs Whips...
# 47  Live Nation Entertainment Rises 22% in a Year:...
# 48  4 Tech Stocks Penetrating the Health and Fitne...
# 49  Inquiry Into Apple's Competitor Dynamics In Te...
#
#                                                   url   time_published  \
# 0   https://www.benzinga.com/tech/25/03/44544129/e...  20250328T190544
# 1   https://www.benzinga.com/markets/equities/25/0...  20250328T161558
# 2   https://www.benzinga.com/insights/news/25/03/4...  20250328T150055
# 3   https://www.benzinga.com/insights/options/25/0...  20250328T134533
# 4   https://www.benzinga.com/markets/equities/25/0...  20250328T125805
# 5   https://www.benzinga.com/markets/25/03/4453457...  20250328T122729
# 6   https://www.zacks.com/stock/news/2436613/3-nor...  20250328T111100
# 7   https://www.fool.com/investing/2025/03/28/2-br...  20250328T110700
# 8   https://www.benzinga.com/25/03/44532855/intels...  20250328T104410
# 9   https://www.zacks.com/stock/news/2436589/shoul...  20250328T102007
# 10  https://www.zacks.com/stock/news/2436592/shoul...  20250328T102005
# 11  https://www.fool.com/investing/2025/03/28/3-wa...  20250328T090600
# 12  https://www.benzinga.com/insights/news/25/03/4...  20250327T150057
# 13  https://www.fool.com/investing/2025/03/27/pred...  20250327T144237
# 14  https://www.benzinga.com/markets/equities/25/0...  20250327T135059
# 15  https://www.zacks.com/stock/news/2436001/can-t...  20250327T120000
# 16  https://www.fool.com/investing/2025/03/27/is-n...  20250327T103000
# 17  https://www.fool.com/investing/2025/03/27/appl...  20250327T101500
# 18  https://www.fool.com/investing/2025/03/27/is-a...  20250327T094500
# 19  https://www.benzinga.com/media/25/03/44509405/...  20250327T094326
# 20  https://www.zacks.com/stock/news/2435946/zacks...  20250327T090000
# 21  https://www.zacks.com/stock/news/2435945/zacks...  20250327T090000
# 22  https://www.benzinga.com/markets/asia/25/03/44...  20250327T074237
# 23  https://www.benzinga.com/tech/25/03/44506409/s...  20250327T005639
# 24  https://www.zacks.com/commentary/2435922/break...  20250326T225600
# 25  https://www.zacks.com/commentary/2435925/break...  20250326T225100
# 26  https://www.fool.com/investing/2025/03/26/2-wo...  20250326T222300
# 27  https://www.zacks.com/stock/news/2435844/apple...  20250326T214516
# 28  https://www.benzinga.com/general/gaming/25/03/...  20250326T153000
# 29  https://www.zacks.com/commentary/2435179/these...  20250326T151500
# 30  https://www.benzinga.com/insights/news/25/03/4...  20250326T150051
# 31  https://www.zacks.com/stock/news/2435683/the-z...  20250326T144800
# 32  https://www.benzinga.com/etfs/broad-u-s-equity...  20250326T140440
# 33  https://www.zacks.com/stock/news/2435394/stock...  20250326T132900
# 34  https://www.benzinga.com/25/03/44492590/alibab...  20250326T123553
# 35  https://www.zacks.com/stock/news/2435228/shoul...  20250326T102006
# 36  https://www.zacks.com/stock/news/2435231/is-vi...  20250326T102006
# 37  https://www.zacks.com/stock/news/2435232/shoul...  20250326T102005
# 38  https://www.zacks.com/stock/news/2435240/is-wi...  20250326T102004
# 39  https://www.fool.com/investing/2025/03/26/nasd...  20250326T084500
# 40  https://www.fool.com/investing/2025/03/26/3-re...  20250326T071100
# 41  https://www.benzinga.com/markets/25/03/4448643...  20250326T023821
# 42  https://www.fool.com/investing/2025/03/25/the-...  20250326T013400
# 43  https://www.benzinga.com/government/regulation...  20250325T231956
# 44  https://www.zacks.com/stock/news/2435040/arm-s...  20250325T172600
# 45  https://www.zacks.com/stock/news/2435030/spoti...  20250325T171100
# 46  https://www.benzinga.com/markets/equities/25/0...  20250325T155000
# 47  https://www.zacks.com/stock/news/2434927/live-...  20250325T152300
# 48  https://www.zacks.com/stock/news/2434924/4-tec...  20250325T151700
# 49  https://www.benzinga.com/insights/news/25/03/4...  20250325T150049
#
#                         authors  \
# 0                 [Chris Katje]
# 1            [The Arora Report]
# 2           [Benzinga Insights]
# 3           [Benzinga Insights]
# 4                        [RIPS]
# 5                 [Namrata Sen]
# 6       [Zacks Equity Research]
# 7               [Anders Bylund]
# 8              [Rishabh Mishra]
# 9       [Zacks Equity Research]
# 10      [Zacks Equity Research]
# 11              [Sean Williams]
# 12          [Benzinga Insights]
# 13              [James Brumley]
# 14                       [RIPS]
# 15  [Zacks Investment Research]
# 16     [CFA, Parkev Tatevosian]
# 17               [Travis Hoium]
# 18               [Jose Najarro]
# 19             [Ananya Gairola]
# 20  [Zacks Investment Research]
# 21  [Zacks Investment Research]
# 22         [Kaustubh Bagalkote]
# 23             [Ananya Gairola]
# 24                [Sheraz Mian]
# 25                [Sheraz Mian]
# 26               [Matt Frankel]
# 27      [Zacks Equity Research]
# 28                [Adam Eckert]
# 29                [Derek Lewis]
# 30          [Benzinga Insights]
# 31      [Zacks Equity Research]
# 32                       [RIPS]
# 33      [Zacks Equity Research]
# 34             [Anusuya Lahiri]
# 35      [Zacks Equity Research]
# 36      [Zacks Equity Research]
# 37      [Zacks Equity Research]
# 38      [Zacks Equity Research]
# 39            [David Jagielski]
# 40               [Matt DiLallo]
# 41             [Ananya Gairola]
# 42              [Keithen Drury]
# 43             [Erica Kollmann]
# 44         [Shuvra Shankar Dey]
# 45         [Shuvra Shankar Dey]
# 46           [The Arora Report]
# 47      [Zacks Equity Research]
# 48                 [Subham Roy]
# 49          [Benzinga Insights]
#
#                                               summary  \
# 0   Benzinga readers pick their favorite Magnifice...
# 1   To gain an edge, this is what you need to know...
# 2   Amidst the fast-paced and highly competitive b...
# 3   Investors with a lot of money to spend have ta...
# 4   Good Morning Traders! In today's Market Clubho...
# 5   The European Union ( EU ) is reportedly set to...
# 6   Invest in Northern mutual funds like NOIEX, NM...
# 7   Looking for undervalued stocks with explosive ...
# 8   Intel Corp. INTC SuperFluid cooling tech could...
# 9                        Style Box ETF report for ...
# 10                       Style Box ETF report for ...
# 11  The Oracle of Omaha may not be tech-savvy, but...
# 12  In today's rapidly changing and fiercely compe...
# 13  Investors aren't looking far enough down the r...
# 14  Good Morning Traders! In today's Market Clubho...
# 15  Mag-7 stocks can gain winning momentum but rem...
# 16  In the race to the coveted $5 trillion market ...
# 17  Microsoft stock went nowhere for over a decade...
# 18  Is Apple entering the artificial intelligence ...
# 19  Apple Inc. AAPL is reportedly making a change ...
# 20  Verizon, Apple and NVIDIA have been highlighte...
# 21  Meta, Tesla, Nvidia, Google, Microsoft, Amazon...
# 22  Foxconn Technology Group, also known as Hon Ha...
# 23  More than three decades ago, Apple Inc. AAPL c...
# 24  The Magnificent 7 stocks have lost ground late...
# 25  The Magnificent 7 stocks have lost ground late...
# 26  After a bit of a rebound, the Nasdaq Composite...
# 27  Apple (AAPL) closed the most recent trading da...
# 28  Meta is luring in VR programmers with "unusual...
# 29  Strong cash flows reflect financial stability,...
# 30  Amidst the fast-paced and highly competitive b...
# 31  Apple, Alphabet, Garmin and Meta are part of t...
# 32  Good Morning Traders! In today's Market Clubho...
# 33  U.S. stocks ended higher on Tuesday on optimis...
# 34  Alibaba and BMW to co-develop AI assistant usi...
# 35                       Style Box ETF report for ...
# 36                      Smart Beta ETF report for ...
# 37                  Style Box ETF report for GUSA ...
# 38                      Smart Beta ETF report for ...
# 39  The Nasdaq Composite is down 9.1% this year an...
# 40  Berkshire Hathaway ( NYSE: BRK.B ) ( NYSE: BRK...
# 41  Taiwan Semiconductor Manufacturing Co.'s TSM $...
# 42  The "Magnificent Seven" stocks have been incre...
# 43  Amazon tops the list with 11,000 H-1B visa app...
# 44  Given the recent fall in Arm Holdings shares, ...
# 45  Given SPOT's price rise, we analyze its curren...
# 46  To gain an edge, this is what you need to know...
# 47  LYV is well-positioned for growth in 2025 with...
# 48  Let's take a look at four tech stocks, AAPL, G...
# 49  In today's rapidly changing and fiercely compe...
#
#                                          banner_image            source  \
# 0   https://cdn.benzinga.com/files/images/story/20...          Benzinga
# 1   https://thearorareport.com/wp-content/uploads/...          Benzinga
# 2   https://www.benzinga.com/files/images/story/20...          Benzinga
# 3   https://www.benzinga.com/files/images/story/20...          Benzinga
# 4   https://www.benzinga.com/next-assets/images/sc...          Benzinga
# 5   https://cdn.benzinga.com/files/images/story/20...          Benzinga
# 6   https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 7   https://g.foolcdn.com/editorial/images/812691/...       Motley Fool
# 8   https://editorial-assets.benzinga.com/wp-conte...          Benzinga
# 9   https://staticx-tuner.zacks.com/images/default...  Zacks Commentary
# 10  https://staticx-tuner.zacks.com/images/default...  Zacks Commentary
# 11  https://g.foolcdn.com/image/?url=https%3A%2F%2...       Motley Fool
# 12  https://www.benzinga.com/files/images/story/20...          Benzinga
# 13  https://g.foolcdn.com/editorial/images/812659/...       Motley Fool
# 14  https://www.benzinga.com/next-assets/images/sc...          Benzinga
# 15  https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 16  https://g.foolcdn.com/editorial/images/812609/...       Motley Fool
# 17  https://g.foolcdn.com/editorial/images/812588/...       Motley Fool
# 18  https://g.foolcdn.com/editorial/images/812645/...       Motley Fool
# 19  https://editorial-assets.benzinga.com/wp-conte...          Benzinga
# 20  https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 21  https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 22  https://cdn.benzinga.com/files/images/story/20...          Benzinga
# 23  https://cdn.benzinga.com/files/images/story/20...          Benzinga
# 24  https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 25  https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 26  https://g.foolcdn.com/editorial/images/812349/...       Motley Fool
# 27  https://staticx-tuner.zacks.com/images/default...  Zacks Commentary
# 28  https://cdn.benzinga.com/files/images/story/20...          Benzinga
# 29  https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 30  https://www.benzinga.com/files/images/story/20...          Benzinga
# 31  https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 32  https://www.benzinga.com/next-assets/images/sc...          Benzinga
# 33  https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 34  https://cdn.benzinga.com/files/images/story/20...          Benzinga
# 35  https://staticx-tuner.zacks.com/images/default...  Zacks Commentary
# 36  https://staticx-tuner.zacks.com/images/default...  Zacks Commentary
# 37  https://staticx-tuner.zacks.com/images/default...  Zacks Commentary
# 38  https://staticx-tuner.zacks.com/images/default...  Zacks Commentary
# 39  https://g.foolcdn.com/editorial/images/812126/...       Motley Fool
# 40  https://g.foolcdn.com/editorial/images/812290/...       Motley Fool
# 41  https://cdn.benzinga.com/files/images/story/20...          Benzinga
# 42  https://media.ycharts.com/charts/07e8c58fe591e...       Motley Fool
# 43  https://cdn.benzinga.com/files/images/story/20...          Benzinga
# 44  https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 45  https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 46  https://thearorareport.com/wp-content/uploads/...          Benzinga
# 47  https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 48  https://staticx-tuner.zacks.com/images/article...  Zacks Commentary
# 49  https://www.benzinga.com/files/images/story/20...          Benzinga
#
#    category_within_source     source_domain  \
# 0                 Trading  www.benzinga.com
# 1                 Markets  www.benzinga.com
# 2                 Trading  www.benzinga.com
# 3                 Markets  www.benzinga.com
# 4                 Trading  www.benzinga.com
# 5                 Markets  www.benzinga.com
# 6                     n/a     www.zacks.com
# 7                     n/a      www.fool.com
# 8                 Markets  www.benzinga.com
# 9                     n/a     www.zacks.com
# 10                    n/a     www.zacks.com
# 11                    n/a      www.fool.com
# 12                Trading  www.benzinga.com
# 13                    n/a      www.fool.com
# 14                Trading  www.benzinga.com
# 15                    n/a     www.zacks.com
# 16                    n/a      www.fool.com
# 17                    n/a      www.fool.com
# 18                    n/a      www.fool.com
# 19                   News  www.benzinga.com
# 20                    n/a     www.zacks.com
# 21                    n/a     www.zacks.com
# 22                Markets  www.benzinga.com
# 23                   News  www.benzinga.com
# 24                    n/a     www.zacks.com
# 25                    n/a     www.zacks.com
# 26                    n/a      www.fool.com
# 27                    n/a     www.zacks.com
# 28                General  www.benzinga.com
# 29                    n/a     www.zacks.com
# 30                Markets  www.benzinga.com
# 31                    n/a     www.zacks.com
# 32                Trading  www.benzinga.com
# 33                    n/a     www.zacks.com
# 34                   News  www.benzinga.com
# 35                    n/a     www.zacks.com
# 36                    n/a     www.zacks.com
# 37                    n/a     www.zacks.com
# 38                    n/a     www.zacks.com
# 39                    n/a      www.fool.com
# 40                    n/a      www.fool.com
# 41                Markets  www.benzinga.com
# 42                    n/a      www.fool.com
# 43                   News  www.benzinga.com
# 44                    n/a     www.zacks.com
# 45                    n/a     www.zacks.com
# 46                General  www.benzinga.com
# 47                    n/a     www.zacks.com
# 48                    n/a     www.zacks.com
# 49                Trading  www.benzinga.com
#
#                                                topics  \
# 0   [{'topic': 'Retail & Wholesale', 'relevance_sc...
# 1   [{'topic': 'Technology', 'relevance_score': '0...
# 2   [{'topic': 'Earnings', 'relevance_score': '0.8...
# 3   [{'topic': 'Financial Markets', 'relevance_sco...
# 4   [{'topic': 'Economy - Monetary', 'relevance_sc...
# 5   [{'topic': 'Technology', 'relevance_score': '1...
# 6   [{'topic': 'Financial Markets', 'relevance_sco...
# 7   [{'topic': 'Economy - Monetary', 'relevance_sc...
# 8   [{'topic': 'Financial Markets', 'relevance_sco...
# 9   [{'topic': 'Technology', 'relevance_score': '0...
# 10  [{'topic': 'Financial Markets', 'relevance_sco...
# 11  [{'topic': 'Retail & Wholesale', 'relevance_sc...
# 12  [{'topic': 'Earnings', 'relevance_score': '0.8...
# 13  [{'topic': 'Technology', 'relevance_score': '1...
# 14  [{'topic': 'Technology', 'relevance_score': '0...
# 15  [{'topic': 'Retail & Wholesale', 'relevance_sc...
# 16  [{'topic': 'Technology', 'relevance_score': '0...
# 17  [{'topic': 'Technology', 'relevance_score': '1...
# 18  [{'topic': 'Technology', 'relevance_score': '0...
# 19  [{'topic': 'Earnings', 'relevance_score': '0.4...
# 20  [{'topic': 'Financial Markets', 'relevance_sco...
# 21  [{'topic': 'Retail & Wholesale', 'relevance_sc...
# 22  [{'topic': 'Technology', 'relevance_score': '0...
# 23  [{'topic': 'Technology', 'relevance_score': '0...
# 24  [{'topic': 'Retail & Wholesale', 'relevance_sc...
# 25  [{'topic': 'Retail & Wholesale', 'relevance_sc...
# 26  [{'topic': 'Financial Markets', 'relevance_sco...
# 27  [{'topic': 'Earnings', 'relevance_score': '0.9...
# 28  [{'topic': 'Technology', 'relevance_score': '1...
# 29  [{'topic': 'Financial Markets', 'relevance_sco...
# 30  [{'topic': 'Earnings', 'relevance_score': '0.8...
# 31  [{'topic': 'Financial Markets', 'relevance_sco...
# 32  [{'topic': 'Economy - Monetary', 'relevance_sc...
# 33  [{'topic': 'Economy - Monetary', 'relevance_sc...
# 34  [{'topic': 'Technology', 'relevance_score': '0...
# 35  [{'topic': 'Financial Markets', 'relevance_sco...
# 36  [{'topic': 'Technology', 'relevance_score': '0...
# 37  [{'topic': 'Financial Markets', 'relevance_sco...
# 38  [{'topic': 'Earnings', 'relevance_score': '0.9...
# 39  [{'topic': 'Financial Markets', 'relevance_sco...
# 40  [{'topic': 'Financial Markets', 'relevance_sco...
# 41  [{'topic': 'Technology', 'relevance_score': '0...
# 42  [{'topic': 'Retail & Wholesale', 'relevance_sc...
# 43  [{'topic': 'Retail & Wholesale', 'relevance_sc...
# 44  [{'topic': 'IPO', 'relevance_score': '0.310843...
# 45  [{'topic': 'Retail & Wholesale', 'relevance_sc...
# 46  [{'topic': 'Economy - Monetary', 'relevance_sc...
# 47  [{'topic': 'Earnings', 'relevance_score': '0.6...
# 48  [{'topic': 'Financial Markets', 'relevance_sco...
# 49  [{'topic': 'Earnings', 'relevance_score': '0.8...
#
#     overall_sentiment_score overall_sentiment_label  \
# 0                  0.266216        Somewhat-Bullish
# 1                  0.240809        Somewhat-Bullish
# 2                  0.265078        Somewhat-Bullish
# 3                  0.185008        Somewhat-Bullish
# 4                  0.084859                 Neutral
# 5                 -0.103777                 Neutral
# 6                  0.272886        Somewhat-Bullish
# 7                  0.298788        Somewhat-Bullish
# 8                  0.226797        Somewhat-Bullish
# 9                  0.183048        Somewhat-Bullish
# 10                 0.201283        Somewhat-Bullish
# 11                 0.351273                 Bullish
# 12                 0.265092        Somewhat-Bullish
# 13                 0.070346                 Neutral
# 14                 0.145910                 Neutral
# 15                 0.250291        Somewhat-Bullish
# 16                 0.108227                 Neutral
# 17                 0.092140                 Neutral
# 18                 0.117406                 Neutral
# 19                 0.218482        Somewhat-Bullish
# 20                 0.391871                 Bullish
# 21                 0.247812        Somewhat-Bullish
# 22                 0.225838        Somewhat-Bullish
# 23                -0.031736                 Neutral
# 24                 0.231884        Somewhat-Bullish
# 25                 0.231884        Somewhat-Bullish
# 26                 0.194173        Somewhat-Bullish
# 27                 0.087162                 Neutral
# 28                 0.108467                 Neutral
# 29                 0.345548        Somewhat-Bullish
# 30                 0.276249        Somewhat-Bullish
# 31                 0.281319        Somewhat-Bullish
# 32                 0.182323        Somewhat-Bullish
# 33                 0.078153                 Neutral
# 34                 0.271142        Somewhat-Bullish
# 35                 0.258124        Somewhat-Bullish
# 36                 0.229911        Somewhat-Bullish
# 37                 0.173142        Somewhat-Bullish
# 38                 0.222288        Somewhat-Bullish
# 39                 0.118379                 Neutral
# 40                 0.391278                 Bullish
# 41                 0.052847                 Neutral
# 42                 0.226443        Somewhat-Bullish
# 43                 0.145920                 Neutral
# 44                 0.369049                 Bullish
# 45                 0.537158                 Bullish
# 46                 0.202329        Somewhat-Bullish
# 47                 0.392535                 Bullish
# 48                 0.285962        Somewhat-Bullish
# 49                 0.282258        Somewhat-Bullish
#
#                                      ticker_sentiment
# 0   [{'ticker': 'MSFT', 'relevance_score': '0.1984...
# 1   [{'ticker': 'MSFT', 'relevance_score': '0.1725...
# 2   [{'ticker': 'AAPL', 'relevance_score': '0.4680...
# 3   [{'ticker': 'EVR', 'relevance_score': '0.06568...
# 4   [{'ticker': 'MSFT', 'relevance_score': '0.0813...
# 5   [{'ticker': 'META', 'relevance_score': '0.2658...
# 6   [{'ticker': 'MSFT', 'relevance_score': '0.1496...
# 7   [{'ticker': 'NFLX', 'relevance_score': '0.1478...
# 8   [{'ticker': 'NVDA', 'relevance_score': '0.4078...
# 9   [{'ticker': 'MSFT', 'relevance_score': '0.1331...
# 10  [{'ticker': 'MSFT', 'relevance_score': '0.1235...
# 11  [{'ticker': 'MSFT', 'relevance_score': '0.0342...
# 12  [{'ticker': 'AAPL', 'relevance_score': '0.4811...
# 13  [{'ticker': 'AAPL', 'relevance_score': '0.7575...
# 14  [{'ticker': 'MSFT', 'relevance_score': '0.0537...
# 15  [{'ticker': 'BABA', 'relevance_score': '0.1028...
# 16  [{'ticker': 'NVDA', 'relevance_score': '0.9836...
# 17  [{'ticker': 'MSFT', 'relevance_score': '0.9495...
# 18  [{'ticker': 'NVDA', 'relevance_score': '0.9309...
# 19  [{'ticker': 'AAPL', 'relevance_score': '0.7929...
# 20  [{'ticker': 'VZ', 'relevance_score': '0.211191...
# 21  [{'ticker': 'MSFT', 'relevance_score': '0.0845...
# 22  [{'ticker': 'MSBHF', 'relevance_score': '0.119...
# 23  [{'ticker': 'AAPL', 'relevance_score': '0.2923...
# 24  [{'ticker': 'MSFT', 'relevance_score': '0.0812...
# 25  [{'ticker': 'MSFT', 'relevance_score': '0.0812...
# 26  [{'ticker': 'MSFT', 'relevance_score': '0.0707...
# 27  [{'ticker': 'AAPL', 'relevance_score': '0.5387...
# 28  [{'ticker': 'GOOG', 'relevance_score': '0.1316...
# 29  [{'ticker': 'VZ', 'relevance_score': '0.251032...
# 30  [{'ticker': 'AAPL', 'relevance_score': '0.4669...
# 31  [{'ticker': 'GOOG', 'relevance_score': '0.0684...
# 32  [{'ticker': 'MSFT', 'relevance_score': '0.1036...
# 33  [{'ticker': 'NVDA', 'relevance_score': '0.0884...
# 34  [{'ticker': 'BABA', 'relevance_score': '0.5341...
# 35  [{'ticker': 'MSFT', 'relevance_score': '0.1261...
# 36  [{'ticker': 'ORCL', 'relevance_score': '0.1130...
# 37  [{'ticker': 'MSFT', 'relevance_score': '0.1316...
# 38  [{'ticker': 'GOOG', 'relevance_score': '0.0574...
# 39  [{'ticker': 'AMD', 'relevance_score': '0.34636...
# 40  [{'ticker': 'BAC', 'relevance_score': '0.05707...
# 41  [{'ticker': 'NVDA', 'relevance_score': '0.0940...
# 42  [{'ticker': 'MSFT', 'relevance_score': '0.1646...
# 43  [{'ticker': 'MSFT', 'relevance_score': '0.1702...
# 44  [{'ticker': 'SSNLF', 'relevance_score': '0.061...
# 45  [{'ticker': 'SPOT', 'relevance_score': '0.4950...
# 46  [{'ticker': 'MSFT', 'relevance_score': '0.0881...
# 47  [{'ticker': 'LYV', 'relevance_score': '0.44233...
# 48  [{'ticker': 'GOOG', 'relevance_score': '0.1408...
# 49  [{'ticker': 'AAPL', 'relevance_score': '0.4723...

# %% [markdown]
# ## volatility

# %%
# Flatten MultiIndex columns 
tsla.columns = [
    '_'.join(col).strip() if isinstance(col, tuple) else col
    for col in tsla.columns
]

# Calculate True Range
tsla["prev_close"] = tsla["Close_TSLA"].shift(1)
tsla["tr1"] = tsla["High_TSLA"] - tsla["Low_TSLA"]
tsla["tr2"] = abs(tsla["High_TSLA"] - tsla["prev_close"])
tsla["tr3"] = abs(tsla["Low_TSLA"] - tsla["prev_close"])

tsla["true_range"] = tsla[["tr1", "tr2", "tr3"]].max(axis=1)

# 10-day ATR
tsla["ATR_10"] = tsla["true_range"].rolling(window=10).mean()

# ---- STEP 4: Calculate ATR as a percentage of closing price ----
tsla["atr_pct"] = tsla["ATR_10"] / tsla["Close_TSLA"]

# allocating the capital

def position_size(row):
    if row["atr_pct"] < 0.03:  # < 3% volatility → low risk
        return 0.01  # allocate 1% of capital
    else:  # ≥ 3% volatility → high risk
        return 0.005  # allocate 0.5% of capital

tsla["position_size"] = tsla.apply(position_size, axis=1)

# ---- STEP 6: Optional - Capital allocation per trade ----
#capital = 100000 # Example: $100K total portfolio
#tsla["allocation_dollars"] = tsla["position_size"] * capital

# ---- Preview ----
print(tsla[["Close_TSLA", "ATR_10", "atr_pct", "position_size"]].tail(10))
# Out:
#             Close_TSLA     ATR_10   atr_pct  position_size
# Date
# 2025-02-19  360.559998  16.703000  0.046325          0.005
# 2025-02-20  354.399994  16.464999  0.046459          0.005
# 2025-02-21  337.799988  17.021997  0.050391          0.005
# 2025-02-24  330.529999  16.770996  0.050740          0.005
# 2025-02-25  302.799988  18.879996  0.062351          0.005
# 2025-02-26  290.799988  18.412994  0.063318          0.005
# 2025-02-27  281.950012  18.257996  0.064756          0.005
# 2025-02-28  292.980011  18.067996  0.061670          0.005
# 2025-03-03  284.649994  19.281998  0.067739          0.005
# 2025-03-04  272.040009  20.654996  0.075926          0.005

# %%
import plotly.express as px
fig = px.line(tsla, x=tsla.index, y="atr_pct", title="ATR% Over Time")
fig.add_hline(y=0.03, line_dash="dot", line_color="green", annotation_text="Low Volatility Cutoff")
fig.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/_plotly_utils/basevalidators.py:106: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   v = v.dt.to_pydatetime()

# %%
import plotly.express as px

# Filter only 2025 data
tsla_2025 = tsla[tsla.index.year == 2025]

# Plot
fig = px.line(tsla_2025, x=tsla_2025.index, y="atr_pct", title="ATR% Over Time (2025 Only)")
fig.add_hline(y=0.03, line_dash="dot", line_color="green", annotation_text="Low Volatility Cutoff")
fig.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/_plotly_utils/basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(
    x=tsla.index,
    y=tsla["VI+_"],
    mode='lines',
    name='VI+_',
    line=dict(color='blue')
))

fig.add_trace(go.Scatter(
    x=tsla.index,
    y=tsla["VI-_"],
    mode='lines',
    name='VI-_',
    line=dict(color='orange')
))

fig.update_layout(
    title="Vortex Indicator (VI+ and VI−) for TSLA",
    xaxis_title="Date",
    yaxis_title="Value",
    legend=dict(x=0, y=1.1, orientation="h"),
    template="plotly_white"
)

fig.show()

# %%
tsla_2025 = tsla.loc["2025"]

fig = go.Figure()

fig.add_trace(go.Scatter(
    x=tsla_2025.index,
    y=tsla_2025["VI+_"],
    mode='lines',
    name='VI+',
    line=dict(color='blue')
))

fig.add_trace(go.Scatter(
    x=tsla_2025.index,
    y=tsla_2025["VI-_"],
    mode='lines',
    name='VI-',
    line=dict(color='orange')
))

fig.update_layout(
    title="Vortex Indicator (VI+ and VI−) for TSLA - 2025",
    xaxis_title="Date",
    yaxis_title="Value",
    legend=dict(x=0, y=1.1, orientation="h"),
    template="plotly_white"
)

fig.show()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=spy.index,
    y=spy["VI+"],
    mode='lines',
    name='VI+',
    line=dict(color='blue')
))

fig.add_trace(go.Scatter(
    x=spy.index,
    y=spy["VI-"],
    mode='lines',
    name='VI-',
    line=dict(color='orange')
))

fig.update_layout(
    title="Vortex Indicator (VI+ and VI−) for SPY",
    xaxis_title="Date",
    yaxis_title="Value",
    legend=dict(x=0, y=1.1, orientation="h"),
    template="plotly_white"
)

fig.show()

# %%
spy_2025 = spy.loc["2025"]

fig = go.Figure()

fig.add_trace(go.Scatter(
    x=spy_2025.index,
    y=spy_2025["VI+"],
    mode='lines',
    name='VI+',
    line=dict(color='blue')
))

fig.add_trace(go.Scatter(
    x=spy_2025.index,
    y=spy_2025["VI-"],
    mode='lines',
    name='VI-',
    line=dict(color='orange')
))

fig.update_layout(
    title="Vortex Indicator (VI+ and VI−) for SPY - 2025",
    xaxis_title="Date",
    yaxis_title="Value",
    legend=dict(x=0, y=1.1, orientation="h"),
    template="plotly_white"
)

fig.show()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=xly.index,
    y=xly["VI+"],
    mode='lines',
    name='VI+',
    line=dict(color='blue')
))

fig.add_trace(go.Scatter(
    x=xly.index,
    y=xly["VI-"],
    mode='lines',
    name='VI-',
    line=dict(color='orange')
))

fig.update_layout(
    title="Vortex Indicator (VI+ and VI−) for XLY",
    xaxis_title="Date",
    yaxis_title="Value",
    legend=dict(x=0, y=1.1, orientation="h"),
    template="plotly_white"
)

fig.show()

# %%
xly_2025 = xly.loc["2025"]

fig = go.Figure()

fig.add_trace(go.Scatter(
    x=xly_2025.index,
    y=xly_2025["VI+"],
    mode='lines',
    name='VI+',
    line=dict(color='blue')
))

fig.add_trace(go.Scatter(
    x=xly_2025.index,
    y=xly_2025["VI-"],
    mode='lines',
    name='VI-',
    line=dict(color='orange')
))

fig.update_layout(
    title="Vortex Indicator (VI+ and VI−) for XLY - 2025",
    xaxis_title="Date",
    yaxis_title="Value",
    legend=dict(x=0, y=1.1, orientation="h"),
    template="plotly_white"
)

fig.show()

# %%
from plotly.subplots import make_subplots

fig = make_subplots(
    rows=3, cols=1,
    subplot_titles=("SPY - 2025", "XLY - 2025", "TSLA - 2025")
)

fig.add_trace(go.Scatter(
    x=spy_2025.index,
    y=spy_2025["VI+"],
    name="VI+ (SPY)",
    line=dict(color='blue'),
    showlegend=False
), row=1, col=1)

fig.add_trace(go.Scatter(
    x=spy_2025.index,
    y=spy_2025["VI-"],
    name="VI- (SPY)",
    line=dict(color='orange'),
    showlegend=False
), row=1, col=1)

fig.add_trace(go.Scatter(
    x=xly_2025.index,
    y=xly_2025["VI+"],
    name="VI+ (XLY)",
    line=dict(color='blue'),
    showlegend=False
), row=2, col=1)

fig.add_trace(go.Scatter(
    x=xly_2025.index,
    y=xly_2025["VI-"],
    name="VI- (XLY)",
    line=dict(color='orange'),
    showlegend=False
), row=2, col=1)

fig.add_trace(go.Scatter(
    x=tsla_2025.index,
    y=tsla_2025["VI+_"],
    name="VI+ (TSLA)",
    line=dict(color='blue'),
    showlegend=False
), row=3, col=1)

fig.add_trace(go.Scatter(
    x=tsla_2025.index,
    y=tsla_2025["VI-_"],
    name="VI- (TSLA)",
    line=dict(color='orange'),
    showlegend=False
), row=3, col=1)

fig.update_layout(
    height=500, width=1200,
    title_text="Vortex Indicator (VI+ and VI−) - 2025 Comparison",
    template="plotly_white"
)

fig.show()

# %%
fig = make_subplots(
    rows=3, cols=1,
    subplot_titles=("SPY Year To Year", "XLY Year To Year", "TSLA Year To Year")
)

fig.add_trace(go.Scatter(
    x=spy.index,
    y=spy["VI+"],
    name="VI+ (SPY)",
    line=dict(color='blue'),
    showlegend=False
), row=1, col=1)

fig.add_trace(go.Scatter(
    x=spy.index,
    y=spy["VI-"],
    name="VI- (SPY)",
    line=dict(color='orange'),
    showlegend=False
), row=1, col=1)

fig.add_trace(go.Scatter(
    x=xly.index,
    y=xly["VI+"],
    name="VI+ (XLY)",
    line=dict(color='blue'),
    showlegend=False
), row=2, col=1)

fig.add_trace(go.Scatter(
    x=xly.index,
    y=xly["VI-"],
    name="VI- (XLY)",
    line=dict(color='orange'),
    showlegend=False
), row=2, col=1)

fig.add_trace(go.Scatter(
    x=tsla.index,
    y=tsla["VI+_"],
    name="VI+ (TSLA)",
    line=dict(color='blue'),
    showlegend=False
), row=3, col=1)

fig.add_trace(go.Scatter(
    x=tsla.index,
    y=tsla["VI-_"],
    name="VI- (TSLA)",
    line=dict(color='orange'),
    showlegend=False
), row=3, col=1)

fig.update_layout(
    height=900, width=1200,
    title_text="Vortex Indicator (VI+ and VI−) - Full Period Comparison",
    template="plotly_white"
)

fig.show()
